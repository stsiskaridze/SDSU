# %% [markdown]
# **Artificial Inteligence (CS550)**
# <br>
# Date: **20 April 2021**
# <br>
#
#
# Title: **Seminar 22**
#
# Speaker: **Dr. Shota Tsiskaridze**
#
#
# Articles:
#
#
# <a href="https://distill.pub/2021/multimodal-neurons/">Multimodal Neurons in Artificial Neural Networks</a>
#
#
# <a href="http://amygdala.psychdept.arizona.edu/IntroData/Readings/week5/Quiroga-reddy-kreiman-koch-Fried+invariant-visual-single-neurons-human+Nature+2005.pdf">Invariant visual representation by single neurons in the human brain<a/>
#
#
# <a href="https://openai.com/blog/clip/#:~:text=We're%20introducing%20a%20neural,%2D2%20and%20GPT%2D3.">CLIP: Connecting Text and Images</a>
#
#
# <a href="https://www.aaai.org/Papers/AAAI/2008/AAAI08-103.pdf">Zero-data Learning of New Tasks</a>

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('Z_kWZpgEZ7w', width=800, height=300)
