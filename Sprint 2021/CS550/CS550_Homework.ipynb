# %% [markdown]
# **CS550 - Artificial Intelligence**
#
# Title: **Homework**
#
# Homework will be evaluated maximum by **30 points**.
# <br>
# Each problem is **two point**.

# %% [markdown]
# <h3 align="center">Problem 1: MixUp Cats and Dogs</h3>
#
# In **Chapter 1** we considered the **Pets** dataset and classify an image as a cat or a dog.
#
# **Mixup**  is a powerful data augmentation technique that can provide dramatically higher accuracy, especially when you don’t have much data and don’t have a pretrained model that was trained on data similar to your dataset.
#
# Mixup works as follows, for each image:
# 1. Select another image from your dataset at random.
# 2. Pick a weight at random.
# 3. Take a weighted average (using the weight from step 2) of the selected image with your image; this will be your independent variable.
# 4. Take a weighted average (with the same weight) of this image’s labels with your image’s labels; this will be your dependent variable.

# %%
# MixUp
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Another technique, Similar to MixUp, is CutMix that cut a random box out of two images and swap them together.
#
# You can look at a few examples below:

# %%
# CutMix
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Tasks:
#
# 1. Consider the **PETS** dataset discussed in Chapter 1.
#
# 2. Using the `resnet18` arcitecture, fit the dataset using MixUp and compare with the initial result.
#
# 3. Try several `epochs = 10` and exlain the observed results.
#
# 4. Using the `resnet18` arcitecture, fit the dataset using CutMix and compare with the initial result.
#
# 5. Try several `epochs = 10` and exlain the observed results.
#
# 6. Why there are no improvements?

# %% [markdown]
# <h3 align="center">Problem 2: Data Augmentation</h3>
#
# Tasks:
#
# 1. Take an image of your choice. The width and height of the image must be greater than $128\times128$!
#
#
# 2. Using the `transforms` method of the `torchvision` library, perform the following data augmentations:
#
#   - Resize the image to the given size. For example `128 x 128`.
#
#   - Crop the center the image of the given size. For example `128 x 128`.
#
#   - Flip the image horizontally or vertically. For example `vertically`.
#
#   - Apply the padding with a given value on all sides. For example using `padding = (1, 2, 3, 4)`.
#
#   - Rotate image at random anlge. For example on `45` degree.
#
#   - Apply the random Affine transformation. For example using `translate=(0.4, 0.5)`.
#
#   - Convert the image into grayscale for augmentation.
#
#   - Apply Color augmentations. For example using `contrast`. Investigate other options!
#
#
# **Note**: Show all image augmentations! Try different parameter values!
#
#
# **Hint**: Read Chapter 2, Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %% [markdown]
# <h3 align="center">Problem 3: MNIST Sample</h3>
#
# In **Chapter 4** we considered the **MNIST_Sample** and classify any image as a $3$ or a $7$.
#
# Tasks:
#
# 1. Instead of looking at $3$ and $7$, go for $4$ and $9$.
#
# 2. Create the `simple_net` (2 layer Linear NN) as considered in the **Chapter 4**.
#
# 3. Instead of ReLU try next activation fucntions: **Sigmoid, Hyperbolic Tangent, Leaky ReLU, Exponential Linear Unit**  and **Swish** Functions.
#
# 4. Fit the models and compare the accuracy.
#
# **Hint**: Read Chapter 4, Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %% [markdown]
# <h3 align="center">Problem 4: Bear Multi-Label Classification</h3>
#
# In **Chapter 4** we considered the **Bear Classification** problem and create an API.
#
# One of the problems with the Bear Classifier was that it could not predict "it is not a bear at all."
#
# Tasks:
#
# 1. Retrain the Bear Classifier using multi-label classification.
#
# 2. See if you can make it work effectively with images that don’t contain any bears.
#
# 3. Check whether the accuracy on the single-label dataset is impacted using multi-label classification.
#
# 4. Create a new API.
#
# **Hint**: Read Chapter 6, Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %% [markdown]
# <h3 align="center">Problem 5: Collaborative Filtering</h3>
#
# The dataset for this problem is available at Kaggle: <a href="https://www.kaggle.com/rymnikski/dataset-for-collaborative-filters"> Songs Dataset</a>
#
# Tasks:
#
# 1. Import required libraries.
#
# 2. Import dataset using the `Pandas` library.
#
# 3. Create the dataloader using the `CollabDataLoaders` class of the `fastai` library and use $20\%$ of our data as part of our validation set.
#
# 4. Create the learner using `colab_learner` class with 30 latent factors.
#
# 5. Fit several cycles using `learning rate = 0.005`.
#
# 6. Optimize **latent factors** and **learning rate** parameters value.
#
#
# **Hint**: Read Chapter 8, Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %% [markdown]
# <h3 align="center">Problem 6: Random Forest for Tabular Data </h3>
#
#
# The dataset for this problem is available at Kaggle: <a href="https://www.kaggle.com/harinir/petrol-consumption/">Petrol Consumption</a>
#
# The problem is to predict the **gas consumption** (in millions of gallons) in 48 of the US states based on **petrol tax** (in cents), per **capita income** (dollars), **paved highways** (in miles) and the **proportion of population with the driving license**.
#
# Tasks:
#
# 1. Import required libraries.
#
# 2. Import dataset using the `Pandas` library.
#
# 3. Split the dataset into training ($80\%$) and test ($20\%$) sets using `train_test_split` of `the sklearn.model_selection` module.
#
# 4. Scale the dataset using `StandardScaler` of `sklearn.preprocessing` module.
#
# 5. Train the model using `RandomForestRegressor` of the `sklearn.ensemble` module.
#
# 6. Build the ``RMSE vs N_estimators`` plot and define the oplimal number of trees in the Random Forest.
#
# 7. Discuss the other `RandomForestRegressor` split criterion attributes. How to they affect the model?
#
# 8. Evaluate the performance of the model using the `metrics` of `sklearn` library.
#
# 9. Build the feature importance plot using the `feature_importances_` attribute of the sklearn’s random forest.
#
# 10. Which one is the most important variable?
#
#
# **Hint**: Read Chapter 9, Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %% [markdown]
# <h3 align="center">Problem 7: Building an GRU from Scratch</h3>
#
# Tasks:
#
# 1. Consider the `Human Numbers` dataset discussed in **Chapter 12**.
#
# 2. Search the internet for the **Gated Recurrent Unit (GRU)** arcitecture.
#
# 3. Implement the **GRU** from scratch like it was done for **LSTM** in **Chapter 12** and train a model.
#
# 4. See if you can get results similar to those for LSTM.
#
#
# **Hint**: Read Chapter 12, Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %% [markdown]
# <h3 align="center">Problem 8: Fit one Cycle</h3>
#
# Given the set of points:

# %%
x = [ 1, 2, 3, 6, 8, 11, 12, 13, 14, 15]
y = [10, 6, 4, 4, 4,  1,  4,  6,  2,  7]

import matplotlib.pyplot as plt
plt.scatter(x, y)

# %% [markdown]
# Tasks:
#
# 1. Fit the datapoints with 9-degree polynomial function using`polyfit` method of the `numpy` library.
#
#
#
# 2. Plot the polynomial function using the `linspace(1, 15, 100)`.
#
#
# 3. Assume the polynomial function is the loss function and perform the Fit One Cycle approach to the gradient descent method to find the stable minimum.
#
#
# 4. Fit One Cycle has the following parameters that you can customize:
#
#   - `lr_max`: The highest learning rate that will be used.
#
#   - `div`: How much to divide `lr_max` by to get the starting learning rate.
#
#   - `div_final`: How much to divide `lr_max` by to get the ending learning rate.
#   - `pct_start`: What percentage of the batches to use for the warmup.
#
#
# 5. Try several starting points for iteration process, for example $x = 1, x = 4, x = 11, x = 14, x = 15$.
#
#
# 6. Adjust the parameters so that the iterative process finds a stable minimum close to $ x = 4 $, no matter which starting point you choose.
#
#
# **Hint**: Read Chapter 13, Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %% [markdown]
# <h3 align="center">Problem 9: ResNet</h3>

# %% [markdown]
# <h3 align="center">Problem 10: U-Net</h3>
