# %% [markdown]
# **Artificial Inteligence (CS550)**
# <br>
# Date: **21 January 2020**
# <br>
#
# Title: **Introduction to AI**
# <br>
# Speaker: **Dr. Shota Tsiskaridze**
#
#
# Bibliography:
# <br>
# [1] Russell, S. & Norvig P., Artificial Intelligence: A Modern Approach, 3rd Edition, Prentice-Hall, 2010
# <br>
# [2] Jeremy Howard & Sylvain Gugger, Deep Learning for Coders with fastai & PyTorch, O'Reilly Media, Inc., 2020

# %%
import graphviz as gv
#hide_input
#caption A program using weight assignment
#id weight_assignment
gv('''model[shape=box3d width=1 height=0.7]
inputs->model->results; weights->model''')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-83897de3e505> in <module>
#       3 #caption A program using weight assignment
#       4 #id weight_assignment
# ----> 5 gv('''model[shape=box3d width=1 height=0.7]
#       6 inputs->model->results; weights->model''')
#
# TypeError: 'module' object is not callable

# %% [markdown]
# <h1 align="center">Introduction to Artificial Intelligence: A Modern Approach</h1>

# %% [markdown]
# <h3 align="center">What Is Machine Learning?</h3>
#
# - Machine learning is, like regular programming, a way to get computers to complete a specific task.
#
#
# - But how would we use regular programming recognize dogs versus cats in photos?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1 align="center">End of Lecture</h1>
