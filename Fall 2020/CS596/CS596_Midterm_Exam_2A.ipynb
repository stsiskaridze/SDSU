# %% [markdown]
# **CS596 - Machine Learning**
# <br>
# Date: **9 November 2020**
# <br>
# Title: **Midterm Exam 2 - Part A**
#
# You will receive a maximum of **10 points** for this part of the exam.
#
#
# **Points are distributed as follows**:
# - Problem 1: **1 point**.
# - Problem 2: **2 point**.
# - Problem 3: **2 point**.
# - Problem 4: **2 point**.
# - Problem 5: **3 point**.

# %% [markdown]
# <h3 align="center">Students ID Number</h3>
#
#
# - In the table below you can see your **ID** number.
#
# - Each student has their own unique **ID**.
#
# | ID |           Student          |
# |:--:|:---------------------------|
# |  1 | Levani   Abuladze          |
# |  2 | Beka Aivazashvili          |
# |  3 | Iza   Akhuashvili          |
# |  4 | Aleksandre   Begiashvili   |
# |  5 | Levan   Berelidze          |
# |  6 | Daviti   Beriashvili       |
# |  7 | Giorgi   Chankseliani      |
# |  8 | Nikoloz   Gabunia          |
# |  9 | Davit Garuchava            |
# | 10 | Nino   Giorgadze           |
# | 11 | Ani Gverdtsiteli           |
# | 12 | Tornike   Iarajuli         |
# | 13 | Tornike   Jajanidze        |
# | 14 | Tamar Jalaghonia           |
# | 15 | Saba   Kalmakhelidze       |
# | 16 | Tinatin   Kotolashvili     |
# | 17 | Alexander   Kutaladze      |
# | 18 | Nineli   Lashkarashvili    |
# | 19 | Giorgi   Machavariani      |
# | 20 | Amiran   Malania           |
# | 21 | Ana   Maludze              |
# | 22 | Giorgi   Meladze           |
# | 23 | Marita   Merabishvili      |
# | 24 | Guga   Mirotadze           |
# | 25 | Giorgi   Natroshvili       |
# | 26 | Giorgi   Sandroshvili      |
# | 27 | Nikoloz   Shalikiani       |
# | 28 | Nino Shareidze             |
# | 29 | Ketevan   Shartava         |
# | 30 | Giorgi   Turdziladze       |

# %% [markdown]
# <h3 align="center">Problem 1A: Calculating the Spatial Size</h3>
#
# - Compute the **spatial size** of the output volume of the Convolutional Layer neuron if the **input volume size** ($W$), the **filter size** ($F$), the **stride** with which they are applied ($S$), and the amount of **zero padding** used ($P$) on the border, are as follows:
#
#   $$\{W, F, S, P\}$$

# %%
# Out:
# Student ID = 1:  W = 5.0,  F = 3.0,  S = 1.0,  P = 0.0.
# Student ID = 2:  W = 5.0,  F = 3.0,  S = 1.0,  P = 1.0.
# Student ID = 3:  W = 5.0,  F = 3.0,  S = 1.0,  P = 2.0.
# Student ID = 4:  W = 5.0,  F = 3.0,  S = 2.0,  P = 0.0.
# Student ID = 5:  W = 5.0,  F = 3.0,  S = 2.0,  P = 1.0.
# Student ID = 6:  W = 5.0,  F = 3.0,  S = 2.0,  P = 2.0.
# Student ID = 7:  W = 5.0,  F = 5.0,  S = 1.0,  P = 0.0.
# Student ID = 8:  W = 5.0,  F = 5.0,  S = 1.0,  P = 1.0.
# Student ID = 9:  W = 5.0,  F = 5.0,  S = 1.0,  P = 2.0.
# Student ID = 10:  W = 5.0,  F = 5.0,  S = 2.0,  P = 0.0.
# Student ID = 11:  W = 5.0,  F = 5.0,  S = 2.0,  P = 1.0.
# Student ID = 12:  W = 5.0,  F = 5.0,  S = 2.0,  P = 2.0.
# Student ID = 13:  W = 6.0,  F = 3.0,  S = 1.0,  P = 0.0.
# Student ID = 14:  W = 6.0,  F = 3.0,  S = 1.0,  P = 1.0.
# Student ID = 15:  W = 6.0,  F = 3.0,  S = 1.0,  P = 2.0.
# Student ID = 16:  W = 6.0,  F = 3.0,  S = 2.0,  P = 0.0.
# Student ID = 17:  W = 6.0,  F = 3.0,  S = 2.0,  P = 1.0.
# Student ID = 18:  W = 6.0,  F = 3.0,  S = 2.0,  P = 2.0.
# Student ID = 19:  W = 6.0,  F = 5.0,  S = 1.0,  P = 0.0.
# Student ID = 20:  W = 6.0,  F = 5.0,  S = 1.0,  P = 1.0.
# Student ID = 21:  W = 6.0,  F = 5.0,  S = 1.0,  P = 2.0.
# Student ID = 22:  W = 6.0,  F = 5.0,  S = 2.0,  P = 0.0.
# Student ID = 23:  W = 6.0,  F = 5.0,  S = 2.0,  P = 1.0.
# Student ID = 24:  W = 6.0,  F = 5.0,  S = 2.0,  P = 2.0.
# Student ID = 25:  W = 7.0,  F = 3.0,  S = 1.0,  P = 0.0.
# Student ID = 26:  W = 7.0,  F = 3.0,  S = 1.0,  P = 1.0.
# Student ID = 27:  W = 7.0,  F = 3.0,  S = 1.0,  P = 2.0.
# Student ID = 28:  W = 7.0,  F = 3.0,  S = 2.0,  P = 0.0.
# Student ID = 29:  W = 7.0,  F = 3.0,  S = 2.0,  P = 1.0.
# Student ID = 30:  W = 7.0,  F = 3.0,  S = 2.0,  P = 2.0.

# %% [markdown]
# <h3 align="center">Problem 2A: Building Neuron</h3>
#
# - **Express** the entire chain of calculations of the **3-input neuron** with the following pataremters:
#
# $$
# \mathbf{x}= \begin{vmatrix}
# -2 \\ 1 \\-1
# \end{vmatrix},
# \mathbf{w}= \begin{vmatrix}
# 1 \\ -2 \\ 3
# \end{vmatrix}
# ,
# \mathbf{o}= \begin{vmatrix}
# \times \\ + \\ \times \\ +
# \end{vmatrix}
# ,
# b = -\pi
# \text{ and }
# \textbf{Hyperbolic Tangent}
# \text{ activation function.}
# $$
#
# <img src="images/ME2_P2A.png" width="800" alt="Example" />

# %%
# Out:
# Student ID = 1
# x = [1, -2, -3]
# w = [2, 1, -1]
# b = [1]
# o = ['+', '+', '+', '+']
# f = Hyperbolic Tangent Function
#
#
# Student ID = 2
# x = [-1, 0, 2]
# w = [1, -1, 0]
# b = [0]
# o = ['*', '+', '*', '*']
# f = ReLU Function
#
#
# Student ID = 3
# x = [1, 1, 0]
# w = [-2, 0, 1]
# b = [1]
# o = ['+', '*', '*', '*']
# f = Binary Step Function
#
#
# Student ID = 4
# x = [1, 1, 2]
# w = [-2, -1, 1]
# b = [2]
# o = ['*', '+', '*', '+']
# f = Binary Step Function
#
#
# Student ID = 5
# x = [0, 2, -2]
# w = [-3, 0, 2]
# b = [2]
# o = ['*', '*', '*', '*']
# f = Swish Function
#
#
# Student ID = 6
# x = [-1, -1, 1]
# w = [-1, 2, -2]
# b = [2]
# o = ['+', '+', '*', '*']
# f = Exponential Linear Unit Function (with 0.1)
#
#
# Student ID = 7
# x = [0, -2, -2]
# w = [0, -3, 1]
# b = [0]
# o = ['*', '+', '+', '+']
# f = Swish Function
#
#
# Student ID = 8
# x = [1, -1, -1]
# w = [1, 1, 2]
# b = [0]
# o = ['*', '*', '*', '*']
# f = Binary Step Function
#
#
# Student ID = 9
# x = [1, 1, 0]
# w = [-2, -1, -2]
# b = [0]
# o = ['+', '+', '+', '+']
# f = Leaky ReLU Function (with 0.1)
#
#
# Student ID = 10
# x = [1, 0, 2]
# w = [-2, -2, 0]
# b = [1]
# o = ['*', '+', '+', '*']
# f = Swish Function
#
#
# Student ID = 11
# x = [2, 2, 1]
# w = [-1, -2, 0]
# b = [0]
# o = ['*', '*', '+', '+']
# f = Exponential Linear Unit Function (with 0.1)
#
#
# Student ID = 12
# x = [-1, 0, 2]
# w = [-3, 2, -2]
# b = [2]
# o = ['+', '+', '+', '+']
# f = Binary Step Function
#
#
# Student ID = 13
# x = [-3, 1, -2]
# w = [1, -3, 2]
# b = [2]
# o = ['+', '+', '+', '*']
# f = Binary Step Function
#
#
# Student ID = 14
# x = [0, -2, -1]
# w = [-2, -1, 2]
# b = [0]
# o = ['*', '*', '*', '*']
# f = Binary Step Function
#
#
# Student ID = 15
# x = [2, 2, 1]
# w = [0, -1, -1]
# b = [0]
# o = ['+', '*', '+', '+']
# f = Binary Step Function
#
#
# Student ID = 16
# x = [1, -3, 2]
# w = [-3, -1, 0]
# b = [1]
# o = ['*', '+', '*', '*']
# f = Swish Function
#
#
# Student ID = 17
# x = [1, 0, 0]
# w = [2, 2, -2]
# b = [2]
# o = ['+', '+', '*', '*']
# f = Hyperbolic Tangent Function
#
#
# Student ID = 18
# x = [0, -1, -1]
# w = [1, -1, -2]
# b = [0]
# o = ['+', '*', '*', '*']
# f = Swish Function
#
#
# Student ID = 19
# x = [-2, -3, -2]
# w = [-1, 0, -3]
# b = [2]
# o = ['*', '*', '+', '*']
# f = Hyperbolic Tangent Function
#
#
# Student ID = 20
# x = [2, -1, 1]
# w = [0, 0, 0]
# b = [2]
# o = ['+', '*', '+', '+']
# f = Swish Function
#
#
# Student ID = 21
# x = [-2, 0, -2]
# w = [-1, -2, 0]
# b = [1]
# o = ['*', '*', '*', '+']
# f = Swish Function
#
#
# Student ID = 22
# x = [-2, 1, 1]
# w = [0, 1, 0]
# b = [2]
# o = ['*', '*', '*', '+']
# f = Hyperbolic Tangent Function
#
#
# Student ID = 23
# x = [-2, 2, -3]
# w = [-3, -3, 1]
# b = [0]
# o = ['*', '*', '+', '*']
# f = Sigmoid Function
#
#
# Student ID = 24
# x = [2, -2, 1]
# w = [0, 1, 0]
# b = [1]
# o = ['*', '+', '*', '+']
# f = Sigmoid Function
#
#
# Student ID = 25
# x = [-3, -2, 0]
# w = [-3, 0, 1]
# b = [0]
# o = ['*', '+', '+', '*']
# f = ReLU Function
#
#
# Student ID = 26
# x = [-3, -3, -3]
# w = [-2, 0, -3]
# b = [0]
# o = ['*', '+', '+', '+']
# f = Binary Step Function
#
#
# Student ID = 27
# x = [-1, -1, 1]
# w = [1, -1, 2]
# b = [0]
# o = ['+', '+', '+', '+']
# f = Hyperbolic Tangent Function
#
#
# Student ID = 28
# x = [-2, 2, -1]
# w = [0, 0, 1]
# b = [2]
# o = ['*', '+', '*', '*']
# f = Leaky ReLU Function (with 0.1)
#
#
# Student ID = 29
# x = [0, 1, 2]
# w = [-1, 2, -3]
# b = [0]
# o = ['+', '+', '*', '+']
# f = Leaky ReLU Function (with 0.1)
#
#
# Student ID = 30
# x = [1, 2, 1]
# w = [-3, 1, 2]
# b = [1]
# o = ['*', '*', '*', '*']
# f = ReLU Function

# %% [markdown]
# <h3 align="center">Problem 3A: Applying Filters</h3>
#
# - Given the **input layer** of the Convolutional Neural Network.
# - What will be the **output** of the **Conv+RELU layer** of the next filter:
#
#   (You can assume that **stride** is equal to $1$ and **padding** is $0$.)

# %%
# Out:
# Student ID = 1
# Input =
#  [[-1.  2. -1. -4.  1.]
#  [-3.  4. -4. -5. -5.]
#  [-4.  1. -2. -1. -4.]
#  [-5. -4. -3.  3.  2.]
#  [ 1. -4.  4. -1. -5.]]
# Filter =
#  [[-4. -5.  2.]
#  [ 4.  3. -3.]
#  [-4.  2.  1.]]
#
#
# Student ID = 2
# Input =
#  [[ 0.  2. -2. -3. -5.]
#  [ 4. -1. -5.  4. -3.]
#  [ 1. -4. -2.  2. -2.]
#  [ 4. -4. -1. -3. -2.]
#  [ 2.  1.  2. -1. -3.]]
# Filter =
#  [[ 3.  0.  2.]
#  [ 4. -5. -2.]
#  [-4.  3.  0.]]
#
#
# Student ID = 3
# Input =
#  [[-2.  0. -1.  4.  4.]
#  [ 2.  3.  0. -2. -3.]
#  [ 0. -1.  3.  3.  1.]
#  [-1.  2. -3. -1.  4.]
#  [-5.  2. -5.  1. -5.]]
# Filter =
#  [[ 0.  2. -5.]
#  [ 4.  3. -4.]
#  [-2. -3.  3.]]
#
#
# Student ID = 4
# Input =
#  [[-3. -5.  1.  4.  2.]
#  [ 2. -5. -5.  2. -3.]
#  [-5. -3.  2.  1. -5.]
#  [-3.  4.  2. -4.  0.]
#  [-5. -2.  2. -3. -2.]]
# Filter =
#  [[-3.  1. -1.]
#  [ 0. -2. -2.]
#  [-2.  1. -2.]]
#
#
# Student ID = 5
# Input =
#  [[-3. -3. -3.  2.  0.]
#  [-1.  4. -2. -1.  2.]
#  [-3.  0.  2. -1. -2.]
#  [-3.  1. -3. -1.  2.]
#  [ 3. -1.  0. -4.  4.]]
# Filter =
#  [[ 0.  2.  0.]
#  [-1. -4. -1.]
#  [ 0.  4.  3.]]
#
#
# Student ID = 6
# Input =
#  [[-2. -5. -2.  2. -3.]
#  [-4. -4. -4.  0.  4.]
#  [ 3.  1.  0. -2. -1.]
#  [-1.  2.  3. -1.  2.]
#  [-5. -1. -1.  0.  0.]]
# Filter =
#  [[ 0. -4. -4.]
#  [ 0.  3. -5.]
#  [-2. -1. -4.]]
#
#
# Student ID = 7
# Input =
#  [[ 3. -2.  3.  3.  4.]
#  [ 1.  0. -5.  2. -2.]
#  [-3.  2. -2.  3. -5.]
#  [-5.  1.  2.  2. -4.]
#  [-5. -2.  0. -1.  0.]]
# Filter =
#  [[-1.  3.  1.]
#  [-2. -4. -4.]
#  [ 1. -5.  3.]]
#
#
# Student ID = 8
# Input =
#  [[ 1. -4. -3. -4.  1.]
#  [-2. -4.  2.  3.  4.]
#  [-2. -5. -1.  0.  4.]
#  [-1. -3. -1. -5. -4.]
#  [-1. -2.  1. -2. -2.]]
# Filter =
#  [[-5.  4. -1.]
#  [-5. -3. -5.]
#  [-4. -2.  3.]]
#
#
# Student ID = 9
# Input =
#  [[ 1.  4.  3.  3. -5.]
#  [ 3.  4. -5.  3. -1.]
#  [-2.  3.  1.  2.  0.]
#  [ 3.  4. -4.  2. -5.]
#  [-2. -5. -5.  2.  0.]]
# Filter =
#  [[-5. -2. -3.]
#  [ 3.  2. -4.]
#  [ 0.  4. -4.]]
#
#
# Student ID = 10
# Input =
#  [[ 4.  3.  1. -1.  4.]
#  [-4. -3. -4. -1.  2.]
#  [-5. -1. -2. -5. -2.]
#  [ 3. -2.  2.  3.  2.]
#  [-5. -2. -3. -2.  3.]]
# Filter =
#  [[ 4. -3.  4.]
#  [ 2.  1. -1.]
#  [ 1.  3. -4.]]
#
#
# Student ID = 11
# Input =
#  [[-2. -1.  3.  1.  2.]
#  [ 2. -3.  4.  0.  0.]
#  [-2.  3.  1. -5. -2.]
#  [-1. -4.  4.  1.  1.]
#  [ 0.  4.  0. -2. -4.]]
# Filter =
#  [[-5. -3.  0.]
#  [-3.  4. -2.]
#  [-2. -3. -2.]]
#
#
# Student ID = 12
# Input =
#  [[-5.  1.  2.  0.  2.]
#  [-4.  4. -3.  2.  0.]
#  [ 4.  3.  0.  3.  4.]
#  [ 0.  4. -2. -1. -4.]
#  [-5.  1.  3.  4.  0.]]
# Filter =
#  [[ 2. -5.  3.]
#  [ 1. -3. -5.]
#  [ 0. -5. -1.]]
#
#
# Student ID = 13
# Input =
#  [[ 3.  0. -5. -3.  2.]
#  [-5.  2.  4.  1. -5.]
#  [ 3.  1. -2. -2. -4.]
#  [-5. -5.  4.  4.  0.]
#  [ 2.  4. -2. -2. -1.]]
# Filter =
#  [[-1.  3.  1.]
#  [ 4.  2. -3.]
#  [-2.  1. -4.]]
#
#
# Student ID = 14
# Input =
#  [[ 2.  4.  2.  3.  4.]
#  [-3. -4. -1.  4. -2.]
#  [-2. -1. -3. -3. -3.]
#  [-1. -5.  3.  4.  4.]
#  [-5.  3.  4.  3.  2.]]
# Filter =
#  [[ 2.  4.  3.]
#  [ 3. -1.  0.]
#  [-5. -1.  3.]]
#
#
# Student ID = 15
# Input =
#  [[-5. -3.  4. -5. -5.]
#  [-2. -5. -3.  1. -4.]
#  [-2.  2. -3. -2. -4.]
#  [ 4. -2.  0.  4.  1.]
#  [-5.  3. -3. -4. -4.]]
# Filter =
#  [[-3. -5. -1.]
#  [-5. -2.  4.]
#  [ 0. -2. -5.]]
#
#
# Student ID = 16
# Input =
#  [[-3.  0.  0. -4. -3.]
#  [-1. -3.  1. -2. -3.]
#  [ 1. -5. -5.  0. -2.]
#  [ 2.  0.  0.  1.  1.]
#  [-5. -4.  0.  2.  2.]]
# Filter =
#  [[-2.  3. -5.]
#  [-5.  1.  2.]
#  [ 0. -1.  3.]]
#
#
# Student ID = 17
# Input =
#  [[ 3. -3. -3. -3. -3.]
#  [ 0. -5.  3.  2.  4.]
#  [ 2.  2. -1. -2. -1.]
#  [ 4. -5. -2. -3. -4.]
#  [ 3.  3. -1.  1. -4.]]
# Filter =
#  [[-5.  0.  1.]
#  [-3. -1. -1.]
#  [-4. -5.  2.]]
#
#
# Student ID = 18
# Input =
#  [[ 3.  0. -2.  4. -1.]
#  [-1. -5. -1.  1. -2.]
#  [-3.  1. -2.  3.  1.]
#  [ 2. -5.  2.  4.  1.]
#  [ 4. -4. -2.  2.  2.]]
# Filter =
#  [[-2.  4. -3.]
#  [ 1. -3.  2.]
#  [ 3. -2. -5.]]
#
#
# Student ID = 19
# Input =
#  [[ 0.  1.  1. -3.  2.]
#  [-3. -3.  2. -4. -4.]
#  [ 1.  1.  2. -4. -2.]
#  [ 0.  3.  1. -2. -5.]
#  [ 3. -1.  4. -5.  4.]]
# Filter =
#  [[ 2.  2. -3.]
#  [ 1. -3. -2.]
#  [ 3. -4.  1.]]
#
#
# Student ID = 20
# Input =
#  [[ 1.  0.  0.  2.  4.]
#  [ 4.  2.  1.  3.  4.]
#  [ 2.  3.  2.  0. -3.]
#  [-2.  2. -2.  0.  1.]
#  [-4.  3.  4.  2. -5.]]
# Filter =
#  [[ 2.  2. -5.]
#  [-4. -4. -1.]
#  [-5. -3.  1.]]
#
#
# Student ID = 21
# Input =
#  [[ 1. -3.  2.  1. -4.]
#  [-1. -3.  4. -1.  2.]
#  [ 2.  0. -2.  0. -3.]
#  [-4.  3. -4. -5. -3.]
#  [ 3.  3. -1. -2. -3.]]
# Filter =
#  [[ 1. -4. -5.]
#  [ 0.  0.  1.]
#  [ 0.  1.  2.]]
#
#
# Student ID = 22
# Input =
#  [[ 4.  1. -5.  0.  2.]
#  [-1. -3.  3. -1.  4.]
#  [-2. -4.  2.  1. -4.]
#  [ 2. -1.  1. -3. -4.]
#  [ 4. -5. -2.  0. -1.]]
# Filter =
#  [[-2.  0. -3.]
#  [-2. -1.  3.]
#  [-1. -3.  3.]]
#
#
# Student ID = 23
# Input =
#  [[ 0. -3. -5.  2. -2.]
#  [-2.  2.  4.  0.  2.]
#  [-3.  4.  4. -4. -3.]
#  [-3.  1.  1.  3. -2.]
#  [ 3.  4.  4. -1. -3.]]
# Filter =
#  [[ 1. -5. -4.]
#  [ 1.  1. -1.]
#  [ 4.  3. -5.]]
#
#
# Student ID = 24
# Input =
#  [[-5.  1. -1.  3.  2.]
#  [-1.  3. -2. -5. -5.]
#  [ 0.  2. -1.  0.  2.]
#  [-5. -2.  3.  4. -3.]
#  [ 2. -4.  0.  1. -4.]]
# Filter =
#  [[ 3.  3. -5.]
#  [-3. -3. -5.]
#  [-2. -4.  1.]]
#
#
# Student ID = 25
# Input =
#  [[-2.  1. -1. -1. -4.]
#  [-2.  3.  1.  3.  3.]
#  [ 2. -1.  4. -5.  4.]
#  [ 2.  1.  1. -5.  4.]
#  [ 3.  2. -1. -3. -3.]]
# Filter =
#  [[ 1.  0. -4.]
#  [ 0. -1. -2.]
#  [-5. -4. -2.]]
#
#
# Student ID = 26
# Input =
#  [[-4.  4. -3.  2.  3.]
#  [-1. -2.  1.  4. -4.]
#  [ 2. -3.  0.  2.  4.]
#  [ 1. -5. -4.  2.  3.]
#  [-1.  0. -4. -2.  0.]]
# Filter =
#  [[ 2.  2. -2.]
#  [-2.  2.  2.]
#  [-2.  1.  0.]]
#
#
# Student ID = 27
# Input =
#  [[-2. -5.  3. -1. -2.]
#  [ 0.  4. -3. -5. -3.]
#  [ 1.  3.  0.  0.  1.]
#  [-5.  4.  1. -2.  1.]
#  [ 2. -5. -5.  3. -1.]]
# Filter =
#  [[ 3.  2. -4.]
#  [-3.  0.  2.]
#  [-2. -1. -2.]]
#
#
# Student ID = 28
# Input =
#  [[-2.  4.  3.  1. -5.]
#  [-5. -3.  2.  4. -4.]
#  [-2. -2.  4. -2.  4.]
#  [-3.  0.  2.  4. -1.]
#  [ 2.  2.  4. -4.  4.]]
# Filter =
#  [[-2. -5.  2.]
#  [-1.  4.  3.]
#  [ 1. -2. -5.]]
#
#
# Student ID = 29
# Input =
#  [[-1.  1.  3. -3. -1.]
#  [ 1. -1. -4.  1.  4.]
#  [ 3.  4.  3.  0.  4.]
#  [ 0. -5. -5.  1.  0.]
#  [ 1.  3. -2.  2.  0.]]
# Filter =
#  [[-5.  0.  1.]
#  [ 1.  3.  0.]
#  [ 1. -3. -4.]]
#
#
# Student ID = 30
# Input =
#  [[-1. -2. -5. -5. -4.]
#  [-4. -3.  2.  4. -2.]
#  [ 1.  4.  4. -1.  1.]
#  [-2. -2.  2. -4. -2.]
#  [ 1.  0. -1.  3. -2.]]
# Filter =
#  [[-1. -5. -2.]
#  [-4.  2.  4.]
#  [-2.  4.  3.]]

# %% [markdown]
# <h3 align="center">Problem 4A: Applying Pool</h3>
#
# - Given the **input layer** of the Convolutional Neural Network.

# %%
# Out:
# Student ID = 1
# Input =
#  [[-1.  2.  3.  1. -6. -6.]
#  [ 3.  0. -6. -6.  0.  1.]
#  [-5.  3.  5. -5.  5.  1.]
#  [-4. -1. -6.  0.  3.  3.]
#  [ 2.  2.  3.  0. -4.  5.]
#  [-2. -5.  1. -6.  3. -5.]]
#
#
# Student ID = 2
# Input =
#  [[ 4. -4. -1.  2. -5.  5.]
#  [ 3.  5. -6.  2.  5.  0.]
#  [-6.  0.  5. -3.  2.  2.]
#  [ 5. -5. -2. -6. -4. -3.]
#  [-5. -4. -4.  3. -2.  5.]
#  [ 4. -1.  3.  2. -5.  4.]]
#
#
# Student ID = 3
# Input =
#  [[-3. -1. -3.  5. -1. -6.]
#  [ 3.  1. -3.  2. -4. -2.]
#  [ 2. -1. -6.  5. -1. -2.]
#  [ 1.  3. -2. -3. -2.  4.]
#  [-1.  4. -3. -4.  4. -4.]
#  [-1.  3. -2.  0.  0.  4.]]
#
#
# Student ID = 4
# Input =
#  [[ 1. -1. -6.  5.  1.  0.]
#  [ 2.  3.  1.  1. -6.  5.]
#  [-1.  0.  4. -5. -1. -2.]
#  [ 0.  4. -2.  5. -6.  5.]
#  [ 0.  4.  4. -3. -5.  3.]
#  [-2.  3.  3. -6.  2.  4.]]
#
#
# Student ID = 5
# Input =
#  [[-2.  1.  0. -5. -6.  4.]
#  [-3.  3. -3.  1. -4.  0.]
#  [ 1. -5. -3. -1. -2. -3.]
#  [ 4. -5. -2.  0. -5. -6.]
#  [-2.  3. -3.  2.  1.  2.]
#  [ 0. -6. -2. -2.  3.  4.]]
#
#
# Student ID = 6
# Input =
#  [[-5. -2.  4. -1.  1.  0.]
#  [-5. -4. -5.  0. -6. -2.]
#  [-3.  5.  5.  0. -2. -6.]
#  [-5. -2. -2. -3.  5.  5.]
#  [-2.  0.  3. -2.  5. -3.]
#  [-6. -6.  0. -1.  0.  2.]]
#
#
# Student ID = 7
# Input =
#  [[-5.  4.  3.  2. -5. -1.]
#  [-5. -2.  1.  1. -1. -3.]
#  [ 4. -6. -2. -1. -6. -6.]
#  [-6.  5. -6.  4. -4. -5.]
#  [-4. -3. -3.  0.  4. -1.]
#  [ 1.  3. -3.  5.  3.  5.]]
#
#
# Student ID = 8
# Input =
#  [[ 3.  0.  4. -5. -3.  0.]
#  [ 1.  3. -5.  2. -5.  4.]
#  [-1.  5. -2. -4. -5. -6.]
#  [ 0.  4.  5. -6. -4. -3.]
#  [-3.  2. -1. -6. -4. -2.]
#  [ 5.  5. -1.  5.  2.  1.]]
#
#
# Student ID = 9
# Input =
#  [[ 2. -6.  1.  4. -1. -4.]
#  [-6.  5. -3.  2.  4. -3.]
#  [ 0.  1.  3.  3. -4.  4.]
#  [-2.  0.  4. -3.  2.  5.]
#  [ 5. -1.  5. -2.  0.  4.]
#  [-1.  2.  4.  3.  0. -1.]]
#
#
# Student ID = 10
# Input =
#  [[ 4.  1. -5.  3.  4.  5.]
#  [-2.  3.  3.  0.  1.  1.]
#  [ 2.  3. -2. -6.  3. -2.]
#  [ 0.  2.  0.  3.  1.  3.]
#  [-4. -4. -1. -3.  3.  0.]
#  [-1.  2.  0. -3. -4.  5.]]
#
#
# Student ID = 11
# Input =
#  [[-2.  3.  4. -6. -2.  3.]
#  [ 3.  1. -4. -3. -6.  1.]
#  [ 0. -5.  5.  2. -6. -1.]
#  [ 0. -6.  4. -5. -6.  4.]
#  [-6. -4. -5. -6. -1. -2.]
#  [ 2.  1.  2.  2. -2. -2.]]
#
#
# Student ID = 12
# Input =
#  [[-5.  4. -1. -4.  0.  0.]
#  [ 4. -4.  3. -3.  4. -1.]
#  [ 5.  4. -3.  3. -3.  5.]
#  [ 4.  4. -2.  2. -4.  4.]
#  [-4.  2.  0. -6.  2.  2.]
#  [-5.  0.  3. -6. -2.  0.]]
#
#
# Student ID = 13
# Input =
#  [[ 2. -5. -6.  4. -5. -5.]
#  [ 3. -6.  1.  3. -4.  0.]
#  [-2.  0. -1. -6.  3.  3.]
#  [ 0. -3. -5. -3.  3.  3.]
#  [-6. -5. -6. -2.  1.  0.]
#  [-6. -2.  3. -1.  1.  1.]]
#
#
# Student ID = 14
# Input =
#  [[-2.  2. -3.  1.  0. -5.]
#  [-3.  2. -1.  2. -3.  5.]
#  [-1. -2. -6. -5.  5. -3.]
#  [ 4.  5. -3.  0.  2.  2.]
#  [-6. -6. -3.  1. -6. -1.]
#  [-2.  1. -6. -3. -4.  0.]]
#
#
# Student ID = 15
# Input =
#  [[ 1. -3. -6. -3. -1.  5.]
#  [ 1.  5.  2.  3.  2. -3.]
#  [-5.  3. -3. -6.  3. -2.]
#  [ 0.  5. -2.  2. -4. -6.]
#  [ 4.  4. -3. -2.  3. -2.]
#  [-4.  5. -1. -5. -1. -5.]]
#
#
# Student ID = 16
# Input =
#  [[-4.  3. -5. -2.  3. -3.]
#  [ 5. -2.  5. -3. -4.  1.]
#  [-5.  3. -4. -4.  2. -1.]
#  [ 0. -1.  4.  5. -2. -6.]
#  [-5.  1. -5. -3. -3.  5.]
#  [ 2. -2. -5. -2. -1. -4.]]
#
#
# Student ID = 17
# Input =
#  [[ 0.  2. -1. -1.  1.  5.]
#  [-6. -5. -6.  2. -4.  1.]
#  [ 1. -1. -6. -2. -4. -6.]
#  [-3.  3. -4. -6. -1. -6.]
#  [-6.  1. -3. -4.  2.  1.]
#  [ 2. -1. -6. -3. -1.  3.]]
#
#
# Student ID = 18
# Input =
#  [[-3. -5. -3.  5.  0.  2.]
#  [ 2. -4.  4. -4. -4. -6.]
#  [-6.  0.  4. -3.  4.  2.]
#  [-2. -6.  4. -2. -2.  3.]
#  [-4. -4.  1. -6. -5. -3.]
#  [-6.  4. -1. -5.  1. -4.]]
#
#
# Student ID = 19
# Input =
#  [[ 4. -1.  2. -3.  1. -3.]
#  [ 2.  5.  2. -5.  4.  2.]
#  [ 5. -5.  5. -6.  0. -4.]
#  [-2. -1. -4. -6. -4. -6.]
#  [ 4.  0. -2. -2.  3.  5.]
#  [-5. -4. -1.  5.  4. -3.]]
#
#
# Student ID = 20
# Input =
#  [[-3.  3.  5.  2.  0.  2.]
#  [ 4. -2.  0.  1. -5. -2.]
#  [ 1.  4.  2.  2. -6. -3.]
#  [ 3. -3.  4. -1.  2.  4.]
#  [-4.  5. -5.  1. -4.  4.]
#  [-3. -5.  1.  4.  0. -5.]]
#
#
# Student ID = 21
# Input =
#  [[ 0.  0. -4.  4. -1.  2.]
#  [-6. -4. -5. -2.  2.  0.]
#  [-1. -4. -2.  1. -6.  3.]
#  [ 3.  3. -5. -2. -2.  5.]
#  [ 0. -4. -4. -4.  4. -6.]
#  [-1. -2. -6. -2.  5.  3.]]
#
#
# Student ID = 22
# Input =
#  [[-2. -2.  0.  3. -6. -4.]
#  [ 0. -5.  5.  4. -1. -1.]
#  [ 3.  4.  1.  4.  4. -5.]
#  [ 4.  1.  2. -5. -2. -5.]
#  [ 5.  0. -4.  1. -2. -2.]
#  [ 4.  5. -4.  0. -6. -1.]]
#
#
# Student ID = 23
# Input =
#  [[-2.  3.  4. -1. -2. -3.]
#  [ 5.  5. -5. -6. -3.  2.]
#  [-2. -6. -5. -6.  3.  5.]
#  [ 3.  3. -2. -4.  1. -3.]
#  [ 5. -4. -2.  3. -1.  2.]
#  [ 4.  3. -2. -2. -1.  0.]]
#
#
# Student ID = 24
# Input =
#  [[-6. -6. -4. -1.  5. -1.]
#  [-2. -6.  5. -5. -4.  4.]
#  [-4. -6. -6.  0. -2.  1.]
#  [-3.  1.  4.  4.  1. -1.]
#  [ 5. -5. -6. -1. -1. -2.]
#  [-5.  3. -5. -2.  2. -1.]]
#
#
# Student ID = 25
# Input =
#  [[-6.  5. -1. -6. -3. -6.]
#  [-6.  0.  1. -6.  2. -6.]
#  [-6.  0. -6. -2. -5. -2.]
#  [-5. -6.  2.  2. -6.  2.]
#  [-2. -1.  4.  1.  3. -4.]
#  [-4.  4. -5. -5.  0. -3.]]
#
#
# Student ID = 26
# Input =
#  [[-2.  0.  3. -5. -1.  3.]
#  [ 1. -4.  1. -4.  4. -3.]
#  [-1. -4.  3. -4. -1.  1.]
#  [ 1. -2.  0.  0.  5. -1.]
#  [-6.  0. -1. -2. -2. -1.]
#  [ 2.  3.  3. -5.  2. -2.]]
#
#
# Student ID = 27
# Input =
#  [[-3. -1.  4. -6.  5. -6.]
#  [ 4. -2. -6.  1. -6. -6.]
#  [-6.  0.  1.  5.  2.  4.]
#  [-2. -3. -5. -1. -3. -2.]
#  [ 0. -1. -2.  2.  5.  3.]
#  [ 3.  3. -1.  3.  2. -6.]]
#
#
# Student ID = 28
# Input =
#  [[-2.  4. -4. -1. -6.  1.]
#  [-5. -5. -6.  3.  4. -4.]
#  [-5.  3. -3.  5. -4.  3.]
#  [ 5. -1. -3.  1. -3. -5.]
#  [-5.  5.  2. -1. -1.  2.]
#  [ 4. -2. -2. -1. -2. -6.]]
#
#
# Student ID = 29
# Input =
#  [[-4.  0. -3. -4.  3. -6.]
#  [ 4.  3. -3. -3.  3.  5.]
#  [ 5.  1. -5.  5. -5.  4.]
#  [-4. -4. -2. -4. -4.  1.]
#  [-2.  5. -5.  2.  1.  5.]
#  [-2.  3.  0. -3.  3.  2.]]
#
#
# Student ID = 30
# Input =
#  [[-4.  5. -5. -5.  4.  0.]
#  [ 1.  0.  5.  1. -3. -5.]
#  [ 4. -3.  0.  3.  3.  4.]
#  [-4.  1.  3.  3. -5. -2.]
#  [ 0. -5. -1. -1.  0. -3.]
#  [-5.  3.  5.  4. -1. -6.]]

# %% [markdown]
# - What will be the **output** of the **Pooling layer** of the **max operation** with $2 \times 2$ filters  with **stride** equal to $2$:

# %% [markdown]
# <h3 align="center">Problem 5A: LSTM of the Recurrent Neural Network</h3>
#
# - Given the **LSTM Cell** of the Recurrent Neural Network:
#
#   <img src="images/ME2_P5A.png" width="800" alt="Example" />
#
# - **Express** the entire chain of calculations of with the following **parameters**:
#   - $x_t$
#   - $c_{t-1}$,
#   - $h_{t-1}$
#   - $W = [W_f, W_i, W_C, W_o]^T$
#   - $b = [b_f, b_i, b_C, b_o]^T$
#
#
# - **Note**: all numbers should be **rounded** to to the nearest **thousandth** ($0.001$).

# %%
# Out:
# Student ID = 1
# x_t = 2
# c_(t-1) = 1
# h_(t-1) = 1
# W = [[2, 0], [2, 2], [1, 2], [1, 0]]
# b = [2, 0, 1, 0]
#
#
# Student ID = 2
# x_t = 1
# c_(t-1) = 2
# h_(t-1) = 1
# W = [[2, 1], [1, 0], [1, 0], [1, 0]]
# b = [0, 1, 0, 0]
#
#
# Student ID = 3
# x_t = 0
# c_(t-1) = 1
# h_(t-1) = 1
# W = [[2, 1], [2, 2], [0, 1], [2, 1]]
# b = [0, 2, 0, 2]
#
#
# Student ID = 4
# x_t = 2
# c_(t-1) = 0
# h_(t-1) = 0
# W = [[0, 1], [2, 1], [0, 0], [2, 1]]
# b = [2, 1, 1, 0]
#
#
# Student ID = 5
# x_t = 1
# c_(t-1) = 0
# h_(t-1) = 2
# W = [[1, 1], [1, 1], [1, 1], [0, 0]]
# b = [0, 2, 2, 1]
#
#
# Student ID = 6
# x_t = 2
# c_(t-1) = 0
# h_(t-1) = 2
# W = [[1, 1], [1, 0], [0, 1], [0, 2]]
# b = [1, 2, 1, 2]
#
#
# Student ID = 7
# x_t = 2
# c_(t-1) = 1
# h_(t-1) = 1
# W = [[1, 1], [2, 0], [1, 1], [1, 1]]
# b = [0, 2, 2, 1]
#
#
# Student ID = 8
# x_t = 2
# c_(t-1) = 2
# h_(t-1) = 1
# W = [[0, 1], [0, 0], [0, 1], [2, 0]]
# b = [0, 2, 0, 1]
#
#
# Student ID = 9
# x_t = 2
# c_(t-1) = 2
# h_(t-1) = 1
# W = [[1, 1], [1, 1], [2, 0], [1, 2]]
# b = [0, 2, 1, 1]
#
#
# Student ID = 10
# x_t = 0
# c_(t-1) = 2
# h_(t-1) = 0
# W = [[1, 1], [1, 2], [2, 1], [2, 2]]
# b = [2, 0, 2, 2]
#
#
# Student ID = 11
# x_t = 1
# c_(t-1) = 0
# h_(t-1) = 2
# W = [[1, 2], [0, 1], [2, 2], [1, 0]]
# b = [1, 1, 1, 2]
#
#
# Student ID = 12
# x_t = 2
# c_(t-1) = 0
# h_(t-1) = 1
# W = [[0, 2], [1, 2], [0, 0], [0, 1]]
# b = [2, 2, 0, 1]
#
#
# Student ID = 13
# x_t = 0
# c_(t-1) = 0
# h_(t-1) = 1
# W = [[0, 2], [1, 1], [1, 1], [2, 0]]
# b = [2, 2, 2, 0]
#
#
# Student ID = 14
# x_t = 2
# c_(t-1) = 2
# h_(t-1) = 0
# W = [[0, 0], [0, 2], [2, 0], [1, 0]]
# b = [1, 1, 2, 1]
#
#
# Student ID = 15
# x_t = 2
# c_(t-1) = 1
# h_(t-1) = 0
# W = [[1, 0], [1, 1], [2, 0], [0, 2]]
# b = [2, 2, 2, 0]
#
#
# Student ID = 16
# x_t = 1
# c_(t-1) = 2
# h_(t-1) = 2
# W = [[1, 0], [1, 2], [0, 1], [2, 1]]
# b = [1, 1, 0, 2]
#
#
# Student ID = 17
# x_t = 0
# c_(t-1) = 1
# h_(t-1) = 2
# W = [[0, 1], [1, 2], [1, 1], [2, 1]]
# b = [1, 2, 2, 0]
#
#
# Student ID = 18
# x_t = 1
# c_(t-1) = 0
# h_(t-1) = 1
# W = [[1, 2], [0, 0], [2, 2], [0, 2]]
# b = [2, 2, 2, 0]
#
#
# Student ID = 19
# x_t = 2
# c_(t-1) = 0
# h_(t-1) = 1
# W = [[1, 0], [0, 2], [1, 0], [2, 2]]
# b = [0, 2, 1, 0]
#
#
# Student ID = 20
# x_t = 0
# c_(t-1) = 2
# h_(t-1) = 2
# W = [[0, 1], [0, 2], [2, 1], [0, 1]]
# b = [2, 0, 2, 0]
#
#
# Student ID = 21
# x_t = 2
# c_(t-1) = 0
# h_(t-1) = 1
# W = [[1, 1], [1, 0], [2, 2], [0, 2]]
# b = [0, 2, 2, 1]
#
#
# Student ID = 22
# x_t = 1
# c_(t-1) = 2
# h_(t-1) = 0
# W = [[1, 1], [1, 2], [2, 1], [2, 1]]
# b = [2, 2, 2, 2]
#
#
# Student ID = 23
# x_t = 0
# c_(t-1) = 0
# h_(t-1) = 1
# W = [[0, 2], [0, 1], [2, 2], [1, 2]]
# b = [2, 1, 0, 2]
#
#
# Student ID = 24
# x_t = 1
# c_(t-1) = 2
# h_(t-1) = 2
# W = [[1, 0], [1, 1], [2, 2], [0, 2]]
# b = [1, 0, 1, 2]
#
#
# Student ID = 25
# x_t = 1
# c_(t-1) = 0
# h_(t-1) = 2
# W = [[2, 0], [1, 1], [0, 2], [2, 2]]
# b = [2, 2, 2, 0]
#
#
# Student ID = 26
# x_t = 2
# c_(t-1) = 1
# h_(t-1) = 0
# W = [[1, 0], [0, 0], [1, 2], [2, 0]]
# b = [1, 0, 2, 0]
#
#
# Student ID = 27
# x_t = 0
# c_(t-1) = 1
# h_(t-1) = 2
# W = [[1, 2], [1, 2], [1, 1], [2, 1]]
# b = [2, 1, 1, 0]
#
#
# Student ID = 28
# x_t = 0
# c_(t-1) = 0
# h_(t-1) = 1
# W = [[2, 0], [2, 0], [2, 0], [0, 1]]
# b = [0, 1, 2, 0]
#
#
# Student ID = 29
# x_t = 2
# c_(t-1) = 1
# h_(t-1) = 0
# W = [[1, 0], [0, 1], [2, 1], [1, 0]]
# b = [0, 0, 1, 2]
#
#
# Student ID = 30
# x_t = 1
# c_(t-1) = 0
# h_(t-1) = 0
# W = [[0, 2], [2, 0], [0, 0], [0, 0]]
# b = [1, 1, 0, 0]

# %% [markdown]
# <h1 align="center">Wish you good luck!</h1>
