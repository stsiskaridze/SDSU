# %% [markdown]
# **CS560 - Algorithms and Their Analysis**
# <br>
# Date: **7 October 2020**
# <br>
# Title: **Midterm 1 - Part 1B**
#
# You will receive a maximum of **10 points** for this part of the exam.
#
#
# **Points are distributed as follows**:
# - Problem 1: **1 point**.
# - Problem 2: **1 point**.
# - Problem 3: **2 point**.
# - Problem 4: **2 point**.
# - Problem 5: **4 point**.

# %% [markdown]
# <h3 align="center">Students ID Number</h3>
#
#
# - In the table below you can see your **ID** number.
#
# - Each student has their own unique **ID**.
#
# | ID |           Student          |
# |:--:|:---------------------------|
# |  1 | Levani   Abuladze          |
# |  2 | Beka Aivazashvili          |
# |  3 | Iza   Akhuashvili          |
# |  4 | Aleksandre   Begiashvili   |
# |  5 | Levan   Berelidze (He/Him) |
# |  6 | Daviti   Beriashvili       |
# |  7 | Giorgi   Chankseliani      |
# |  8 | Nikoloz   Gabunia          |
# |  9 | Nino   Giorgadze           |
# | 10 | Gocha   Gunashvili         |
# | 11 | Ani   Gverdtsiteli         |
# | 12 | Tornike   Iarajuli         |
# | 13 | Tornike   Jajanidze        |
# | 14 | Saba   Kalmakhelidze       |
# | 15 | Phuad   Karaev             |
# | 16 | Tinatin   Kotolashvili     |
# | 17 | Alexander   Kutaladze      |
# | 18 | Nineli   Lashkarashvili    |
# | 19 | Levan   Lobjanidze         |
# | 20 | Giorgi   Machavariani      |
# | 21 | Amiran   Malania           |
# | 22 | Ana   Maludze              |
# | 23 | Giorgi   Meladze           |
# | 24 | Marita   Merabishvili      |
# | 25 | Guga   Mirotadze           |
# | 26 | Giorgi   Natroshvili       |
# | 27 | Giorgi   Sandroshvili      |
# | 28 | Nikoloz   Shalikiani       |
# | 29 | Giorgi   Sharmiashvili     |
# | 30 | Ketevan   Shartava         |
# | 31 | Giorgi   Turdziladze       |

# %% [markdown]
# <h3 align="center">Problem 1: Build a Heap from an Array</h3>
#
# - Below, a **random array** is generated for each student.
#
#
# - Build a **Heap** from an array matching your **ID** number.
#
#
# - **Note**: You need to **draw** the **binary tree**!

# %%
# Out:
# 1. A = [5, 13, 3, 2, 11, 15, 4, 8, 7, 9, 1, 12, 10, 14, 6]
# 2. A = [4, 15, 3, 14, 13, 7, 11, 1, 5, 8, 10, 12, 9, 2, 6]
# 3. A = [1, 10, 3, 14, 6, 15, 5, 8, 7, 9, 12, 2, 4, 13, 11]
# 4. A = [11, 13, 2, 3, 12, 5, 15, 7, 6, 14, 1, 4, 8, 9, 10]
# 5. A = [1, 2, 12, 11, 9, 8, 10, 6, 7, 14, 4, 3, 15, 13, 5]
# 6. A = [7, 9, 3, 8, 2, 12, 5, 4, 13, 6, 10, 15, 14, 11, 1]
# 7. A = [2, 12, 15, 11, 14, 13, 8, 5, 7, 10, 6, 4, 1, 3, 9]
# 8. A = [12, 8, 3, 9, 7, 2, 15, 10, 13, 1, 11, 4, 14, 5, 6]
# 9. A = [2, 10, 13, 14, 4, 6, 1, 12, 7, 3, 5, 15, 9, 11, 8]
# 10. A = [10, 7, 1, 14, 3, 8, 11, 15, 5, 6, 4, 12, 9, 13, 2]
# 11. A = [13, 5, 15, 1, 3, 14, 7, 10, 9, 4, 11, 6, 8, 2, 12]
# 12. A = [2, 4, 10, 7, 1, 15, 14, 12, 13, 9, 5, 3, 11, 6, 8]
# 13. A = [10, 6, 13, 4, 15, 12, 3, 1, 8, 7, 11, 14, 5, 9, 2]
# 14. A = [3, 1, 14, 5, 9, 4, 7, 13, 12, 2, 6, 11, 8, 10, 15]
# 15. A = [10, 3, 1, 4, 14, 15, 6, 9, 12, 2, 5, 7, 11, 13, 8]
# 16. A = [10, 7, 15, 14, 5, 3, 2, 8, 4, 9, 11, 1, 6, 12, 13]
# 17. A = [6, 1, 2, 11, 4, 8, 13, 15, 12, 5, 10, 7, 3, 14, 9]
# 18. A = [3, 1, 14, 7, 11, 4, 12, 15, 13, 2, 9, 6, 8, 5, 10]
# 19. A = [8, 6, 3, 7, 13, 5, 12, 11, 15, 4, 1, 2, 14, 10, 9]
# 20. A = [4, 6, 10, 15, 8, 9, 14, 2, 7, 13, 5, 1, 3, 12, 11]
# 21. A = [5, 13, 3, 8, 12, 4, 14, 2, 10, 9, 15, 6, 7, 11, 1]
# 22. A = [4, 13, 14, 8, 2, 12, 5, 7, 1, 10, 9, 11, 15, 6, 3]
# 23. A = [4, 8, 3, 15, 7, 9, 12, 6, 2, 5, 10, 13, 14, 11, 1]
# 24. A = [13, 4, 14, 6, 5, 8, 11, 15, 10, 2, 3, 7, 12, 1, 9]
# 25. A = [5, 9, 11, 3, 15, 4, 14, 7, 8, 12, 6, 1, 10, 13, 2]
# 26. A = [11, 13, 7, 1, 6, 5, 8, 4, 14, 3, 12, 2, 10, 15, 9]
# 27. A = [1, 12, 9, 11, 8, 6, 14, 3, 10, 2, 5, 4, 15, 7, 13]
# 28. A = [13, 5, 12, 3, 15, 8, 10, 11, 1, 9, 2, 7, 6, 4, 14]
# 29. A = [5, 14, 10, 1, 4, 8, 2, 11, 15, 13, 7, 3, 9, 6, 12]
# 30. A = [15, 3, 14, 11, 7, 5, 8, 4, 9, 10, 1, 12, 6, 2, 13]
# 31. A = [7, 4, 6, 2, 1, 8, 5, 13, 3, 10, 15, 14, 9, 12, 11]

# %% [markdown]
# <h3 align="center">Problem 2: Build an array from a Heap</h3>
#
# - Below, a **random heap** is generated for each student.
#
#
# - Build an **Array** from a Heap matching your **ID** number.
#
#
# - **Note**: You need to **write down** the **array**!

# %%
# Out:
# 1: ===================================================
#                 9
#         2                  10
#   3          14          11       8
# 13    12    7    1    4    15    6    5
# =======================================================
#
#
# 2: ===================================================
#                 11
#         4                  1
#   6          5          8       7
# 15    3    14    2    10    12    9    13
# =======================================================
#
#
# 3: ===================================================
#                 8
#         7                  11
#   2          1          3       6
# 15    4    13    14    10    12    9    5
# =======================================================
#
#
# 4: ===================================================
#                 14
#         10                  5
#   11          7          6       3
# 15    13    1    12    2    9    4    8
# =======================================================
#
#
# 5: ===================================================
#                 8
#         2                  14
#   5          9          6       10
# 12    15    3    7    11    4    13    1
# =======================================================
#
#
# 6: ===================================================
#                 9
#         4                  8
#   10          11          5       15
# 7    12    1    14    3    13    2    6
# =======================================================
#
#
# 7: ===================================================
#                 14
#         11                  9
#   3          5          1       2
# 6    10    15    12    13    4    7    8
# =======================================================
#
#
# 8: ===================================================
#                 9
#         5                  15
#   4          11          10       13
# 3    12    7    14    1    8    2    6
# =======================================================
#
#
# 9: ===================================================
#                 3
#         1                  12
#   2          8          11       7
# 10    15    9    4    6    13    5    14
# =======================================================
#
#
# 10: ===================================================
#                 1
#         6                  5
#   11          8          13       15
# 10    14    9    4    12    7    2    3
# =======================================================
#
#
# 11: ===================================================
#                 13
#         14                  9
#   4          12          3       5
# 7    1    2    11    10    8    6    15
# =======================================================
#
#
# 12: ===================================================
#                 10
#         11                  7
#   15          5          2       12
# 14    4    3    13    8    9    1    6
# =======================================================
#
#
# 13: ===================================================
#                 6
#         12                  13
#   1          14          9       15
# 4    2    10    7    11    5    8    3
# =======================================================
#
#
# 14: ===================================================
#                 6
#         13                  3
#   11          7          2       15
# 14    10    12    8    4    5    1    9
# =======================================================
#
#
# 15: ===================================================
#                 14
#         8                  13
#   5          1          7       3
# 15    12    9    6    10    11    4    2
# =======================================================
#
#
# 16: ===================================================
#                 3
#         4                  11
#   6          9          8       15
# 2    7    13    14    5    1    12    10
# =======================================================
#
#
# 17: ===================================================
#                 5
#         15                  6
#   14          2          3       11
# 8    9    4    10    12    13    1    7
# =======================================================
#
#
# 18: ===================================================
#                 5
#         4                  8
#   12          13          1       15
# 9    11    3    2    14    7    10    6
# =======================================================
#
#
# 19: ===================================================
#                 10
#         2                  14
#   7          3          4       1
# 11    9    8    15    12    13    5    6
# =======================================================
#
#
# 20: ===================================================
#                 15
#         9                  11
#   2          8          4       3
# 10    5    13    1    6    14    12    7
# =======================================================
#
#
# 21: ===================================================
#                 4
#         10                  15
#   7          9          6       5
# 1    2    11    14    3    8    13    12
# =======================================================
#
#
# 22: ===================================================
#                 12
#         2                  4
#   3          10          9       5
# 7    11    6    14    8    13    1    15
# =======================================================
#
#
# 23: ===================================================
#                 2
#         5                  6
#   4          10          13       8
# 12    11    7    9    14    1    3    15
# =======================================================
#
#
# 24: ===================================================
#                 2
#         13                  9
#   11          5          1       14
# 7    6    3    15    4    10    12    8
# =======================================================
#
#
# 25: ===================================================
#                 1
#         8                  4
#   10          14          12       11
# 5    3    7    2    15    13    9    6
# =======================================================
#
#
# 26: ===================================================
#                 9
#         8                  11
#   3          5          15       6
# 13    14    10    4    2    7    12    1
# =======================================================
#
#
# 27: ===================================================
#                 7
#         6                  10
#   9          8          3       11
# 4    15    12    2    1    5    14    13
# =======================================================
#
#
# 28: ===================================================
#                 12
#         10                  3
#   8          13          14       1
# 15    6    2    7    4    9    11    5
# =======================================================
#
#
# 29: ===================================================
#                 4
#         13                  11
#   5          8          7       1
# 14    10    6    3    9    2    15    12
# =======================================================
#
#
# 30: ===================================================
#                 11
#         12                  3
#   5          4          10       2
# 6    8    7    13    14    1    15    9
# =======================================================
#
#
# 31: ===================================================
#                 8
#         4                  11
#   9          6          12       1
# 13    10    7    5    14    3    2    15
# =======================================================

# %% [markdown]
# <h3 align="center">Problem 3: Build a Max-Heap</h3>
#
# - For the array from **Problem 1**, build the **Max-Heap**.
#
#
# - If it is already **Max-Heap** (it can happen!), then build **Min-Heap**!
#
#
# - **Note**: You need to **draw** the **binary tree** for each of the **Heapify step**!

# %% [markdown]
# <h3 align="center">Problem 4: Solving Recurrence</h3>
#
# - For the recurrence that matches your **ID** number, give an expression for the runtime $T (n)$ if the recurrence can be solved by the **Master Theorem**.
#
# - Otherwise, indicate that the Master Theorem **does not apply**!
#
#
# - **Tasks**:
#   1. Identify $a$, $b$ and $f(n)$ and check the use of the Master Theorem.
#   2. Compare $f(n)$ with $n^{\log_b a}$ and identify which case to use!
#
#
# - **Note**: Do not forget to check **other conditions**!
# - **Note**: Do not forget about **non-polynomial difference** between $f(n)$ with $n^{\log_b a}$!
#
#
# 1. $T(n) = 3T(n/2) + n^2$
# 2. $T(n) = T(n-1) + 1/n$  (**Solve it anyway!**)
# 3. $T(n) = T(n/2) + 2^n$
# 4. $T(n) = 16T(n/4) + n$
# 5. $T(n) = 4T(n/3) + n \log n$
# 6. $T(n) = 3T(n/3) + n \log n$
# 7. $T(n) = 2T(n/4) + n^{0.51}$
# 8. $T(n) = 2T(n/2) + n \log n$
# 9. $T(n) = 16T(n/4) + n!$
# 10. $T(n) = \sqrt{2}T(n/2) + \log n$
# 11. $T(n) = 0.5T(n/2) + 1/n$
# 12. $T(n) = 3T(n/3) + \sqrt{n}$
# 13. $T(n) = 4T(n/2) + cn$
# 14. $T(n) = 3T(n/4) + n \log n$
# 15. $T(n) = 3T(n/3)+ n/2$
# 16. $T(n) = T(n-1) + \lg n$ (**Solve it anyway!**)
# 17. $T(n) = 4T(n/2)+ n/ \log n$
# 18. $T(n) = 7T(n/3)+ n^2$
# 19. $T(n) = 4T(n/2)+ \log n$
# 20. $T(n) = T(7n/10) + n$
# 21. $T(n) = 16T(n/4) + n^2$
# 22. $T(n) = 7T(n/2) + n^2$
# 23. $T(n) = 2T(n/4) + \sqrt{n}$
# 24. $T(n) = 3T(n/3 - 2) + n/2$
# 25. $T(n) = 64T(n/8) − n^2 \log n$
# 26. $T(n) = T(n-1) + n^2$  (**Solve it anyway!**)
# 27. $T(n) = 4T(n/2) + n^2\sqrt{n}$
# 28. $T(n) = 4T(n/2) + n^2$
# 29. $T(n) = 6T(n/3)+ n^2 \log n$
# 30. $T(n) = T(n/2) + T(n/4) + T(n/8) + n$ (**Solve it anyway!**)
# 31. $T(n) = 3T(n/2) + n$
#
#
# - **Note**: you can assume that $T(1) = c_0$.

# %% [markdown]
# <h3 align="center">Master Method</h3>
#
# - **Theorem**: Let $a \geq1$ and $b > 1$ be constants, let $f(n)$ be a function, and let $T(n)$ be defined on the **nonnegative** integers by the recurrence:
#
#   $$T(n) = aT(n/b) + f(n).$$
#
#   Then $T(n)$ has the following **asymptotic bounds**:
#
#   1. If $f(n) = O(n^{\log_b a-\epsilon})$ for some constant $\epsilon > 0$, then $T(n) = \Theta(n^{\log_b a})$.
#   2. If $f(n) = \Theta(n^{\log_b a})$, then $T(n) = \Theta(n^{\log_b a} \lg n)$.
#   3. If $f(n) = \Omega(n^{\log_b a + \epsilon})$ for some constant $\epsilon > 0$, and if $af(n/b) \leq cf(n)$ for some constant $c < 1$ and all sufficiently large $n$, then $T(n) = \Theta(f(n))$.
#
#
# - In otherwords, in each of the **three cases**, we compare the function $f(n)$ with the function $n^{\log_b a}$.
#   - **Case 1**: If the function $n^{\log_b a}$ is the larger, then the solution is $T(n) = \Theta(n^{\log_b a})$.
#   - **Case 2**: If the two functions are the same size, we multiply by a logarithmic factor, and the solution is $T(n) = \Theta(n^{\log_b a} \lg n)$.
#   - **Case 3**: If the function $f(n)$ is the larger, then the solution is $T(n) = \Theta(f(n))$.
#
#
# - **Note** that these three cases **do not cover** all the possibilities for $f(n)$:
#   - In the **first case**, not only must $f(n)$ be smaller than $n^{\log_b a}$, it must be **polynomially smaller**.
#   - In the **third case**, not only must $f(n)$ be larger than $n^{\log_b a}$, it also must be **polynomially larger** and in addition satisfy the **regularity** condition:
#     $$af(n/b) \leq cf(n).$$

# %% [markdown]
# <h3 align="center">Problem 5: Analyzing the Code Running Time</h3>
#
# - Given the code for the `partition` procedure:

# %%
def partition(A, p, r):           
    x = A[r]                    #c1   
    i = p-1                     #c2   
    for j in range(p, r):       #c3   
        if A[j] <= x:           #c4   
            i = i+1             #c5   
            exchange(A, i, j)   #c6   
    exchange(A, i+1, r)         #c7   
    return i+1                  #c8

# %% [markdown]
# - For each line you can see the **constants** $c_1, ..., c_8$ that identifies the **time cost** of the line.
#
#
# - Choose the **case** scenario:
#   - If your **ID** number is **odd**  - consider **best-case** scenario, i.e. when array is sorted in **descending order**.
#   - If your **ID** number ie **even** - consider **worst-case** scenario, i.e. when array is sorted in **ascending order**.
#
#
# - For simplicity, you can assume that $p = 0$ and $r = n-1$, i.e. array consist of $n$ elements.
#
#
# - Tasks:
#   1. **Count** how many **times** each line was executed (**write** this as a comment to the **left of each line**)
#   2. **Write down** the **running time equation** as the **sum of each line**.
#   3. **Group up** and **simplify** the **running time equation**.
#   4. **Get asymptotic notation** for the **running time**.

# %% [markdown]
# <h1 align="center">Wish you good luck!</h1>
